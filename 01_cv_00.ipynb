# %% [markdown]
# # Before we dive into OpenCV, Let´s seee how to manipulate Image w/ Pure Python!
# # [PILLOW LIB](https://pillow.readthedocs.io/en/stable/)
#
# Importing [Numpy](https://numpy.org/) as well [MatplotLib](https://matplotlib.org/)

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('DATA/00_puppy.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=789x551 at 0x21AAAEF2790>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %% [markdown]
# #### To work with Numpy we must convert JPEG image to Numpy Array. Here is how:

# %%
pic_arr = np.asanyarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (551, 789, 3)

# %%
plt.imshow(pic_arr)

# %% [markdown]
# ###  Here's the image and this PLT show, it's kind of a special function that's specially designed to show images that are transformed to as arrays.
# pic_arr.shape
#
#     (551, 789, 3)

# %% [markdown]
# ### Note that there's three channels here, the red, the green and the blue.
#
# ### Each one has its array (551, 789) for Red , (551, 789) for Green and, (551, 789) for Blue.

# %% [markdown]
# ### let's actually access one of these channels by itself

# %%
pic_red = pic_arr[:,:,0]

# %%
# RED CHANNEL VALUES 0-255 0 = NO COLOR ALUE 255 = FULL COLOR
plt.imshow(pic_red, cmap='gray')

# %% [markdown]
# ### So that means when we're actually viewing this in grayscale, the closer to white that means more red for this particular image.

# %%
pic_green = pic_arr[:,:,1]

# %%
plt.imshow(pic_green, cmap='gray')

# %%
pic_blue = pic_arr[:,:,2]

# %%
plt.imshow(pic_blue, cmap='gray')

# %% [markdown]
# ###  So, here we're displaying the three different channels as grayscale.

# %% [markdown]
# ### Now let´s zeroed GB and remaim with R channel

# %%
pic_copy = pic_arr.copy()

# %%
# zeroed out the Green Channel
pic_copy[:,:,1] = 0
# zeroed out the Blue Channel
pic_copy[:,:,2] = 0

# %%
# shows up the RED channel
plt.imshow(pic_copy)

# %% [markdown]
# ### We went ahead and zeroed out the Green Channel as well as the Blue Channel, which is why this picture only shows up with the red.

# %%
pic_copy.shape
# Out:
# (551, 789, 3)

# %% [markdown]
# ### There are 3 channel! because we're seeing all three channels at once instead of just one channel.
# ### what we did was zeroed two channels, but the arrays remain intact even if their values have been set to zero

# %%
print("That's it! Thanks for reading\nNext Episode: OpenCV  Basics\nSee you soon!")
# Out:
# That's it! Thanks for reading
# Next Episode: OpenCV  Basics
# See you soon!
